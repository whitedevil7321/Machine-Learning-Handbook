# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
dataset=load_digits()
dir(dataset)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
df=pd.DataFrame(dataset.data,columns=dataset.feature_names)

# %%
x=df

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[ 0.        , -0.33501649, -0.04308102, ..., -1.14664746,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -1.09493684, ...,  0.54856067,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -1.09493684, ...,  1.56568555,
#          1.6951369 , -0.19600752],
#        ...,
#        [ 0.        , -0.33501649, -0.88456568, ..., -0.12952258,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -0.67419451, ...,  0.8876023 ,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649,  1.00877481, ...,  0.8876023 ,
#         -0.26113572, -0.19600752]])

# %%
y=dataset.target

# %%
lr=LogisticRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y ,test_size=0.2)

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.9986082115518441

# %%
pca=PCA(0.95)

# %%
x_pca=pca.fit_transform(x)

# %%
x_pca.shape
# Out:
# (1797, 29)

# %%
pca_dataset=pd.DataFrame(x_pca)

# %%
pca_dataset
# Out:
#              0          1          2          3   ...        25        26        27        28
# 0     -1.259466 -21.274883   9.463055 -13.014189  ...  2.300582  3.670721  0.943669  1.132502
# 1      7.957611  20.768699  -4.439506  14.893664  ...  0.119213  2.182618  0.510227 -2.313549
# 2      6.991923   9.955986  -2.958558  12.288302  ...  0.166046  4.228821 -2.157657 -0.837958
# 3    -15.906105  -3.332464  -9.824372  12.275838  ... -1.340244 -5.846014 -4.682220  1.113042
# 4     23.306867  -4.269061   5.675129  13.851524  ... -0.166739  0.484305 -0.627979  3.287348
# ...         ...        ...        ...        ...  ...       ...       ...       ...       ...
# 1792 -14.606628 -13.344124  13.439048   6.502950  ... -2.445219  4.914990  0.183197  2.788351
# 1793   6.464574 -20.567299   9.155110 -12.554091  ... -1.134583 -0.048710  0.304789  3.483718
# 1794  10.801284   6.960252  -5.599555   7.227733  ...  4.431521 -3.568662 -1.824444 -3.538859
# ...

# %%
pca_dataset["target"]=dataset.target

# %%
x_pca_values=pca_dataset.drop("target",axis=1)

# %%
y_pca_values=pca_dataset.target

# %%
x_train1,x_test,y_train1,y_test1=train_test_split(x_pca_values,y_pca_values,test_size=0.2)

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train1,y_train1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.score(x_train1,y_train1)
# Out:
# 1.0
